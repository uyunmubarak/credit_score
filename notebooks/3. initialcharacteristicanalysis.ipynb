# %% [markdown]
# ### **3. Initial Characteristic Analysis**

# %% [markdown]
# #### **3.1 Characteristic Binning**

# %%
#import library
import pandas as pd
import numpy as np
import sys
sys.path.append("../src")
#load configuration
import utils

# %%
config_data = utils.config_load()
config_data
# Out:
# {'raw_dataset_path': '../data/raw/Loan_default.csv',
#  'dataset_path': '../data/output/data.pkl',
#  'predictors_set_path': '../data/output/predictors.pkl',
#  'response_set_path': '../data/output/response.pkl',
#  'train_path': ['../data/output/X_train.pkl', '../data/output/y_train.pkl'],
#  'test_path': ['../data/output/X_test.pkl', '../data/output/y_test.pkl'],
#  'data_train_path': '../data/output/training_data.pkl',
#  'data_train_binned_path': '../data/output/bin_training_data.pkl',
#  'crosstab_list_path': '../data/output/list_crosstab.pkl',
#  'WOE_table_path': '../data/output/WOE_table.pkl',
#  'IV_table_path': '../data/output/IV_table.pkl',
#  'WOE_map_dict_path': '../data/output/WOE_map_dict.pkl',
#  'X_train_woe_path': '../data/output/X_train_woe.pkl',
#  'response_variable': 'Default',
#  'test_size': 0.2,
#  'numeric_col': ['Age',
#   'Income',
#   'LoanAmount',
#   'MonthsEmployed',
#   'NumCreditLines',
#   'InterestRate',
#   'LoanTerm',
#   'DTIRatio'],
#  'categoric_col': ['Education',
#   'EmploymentType',
#   'MaritalStatus',
#   'HasMortgage',
#   'HasDependents',
#   'LoanPurpose',
#   'HasCoSigner'],
#  'num_of_bins': 5,
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': '../models/forward_models.pkl',
#  'best_predictors_path': '../models/best_predictors_path.pkl',
#  'best_model_path': '../models/best_model.pkl',
#  'best_model_summary_path': '../models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 200,
#  'odds_ref': 30,
#  'scorecards_path': '../models/scorecards.pkl',
#  'points_map_dict_path': '../models/points_map_dict.pkl',
#  'X_points_path': '../models/X_points.pkl',
#  'X_train_points_path': '../models/X_train_points.pkl',
#  'score_path': '../models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['Age_binned',
#   'DTIRatio_binned',
#   'Education',
#   'EmploymentType',
#   'HasCoSigner',
#   'HasDependents',
#   'HasMortgage',
#   'Income_binned',
#   'InterestRate_binned',
#   'LoanAmount_binned',
#   'LoanPurpose',
#   'LoanTerm_binned',
#   'MaritalStatus',
#   'MonthsEmployed_binned',
#   'NumCreditLines_binned']}

# %%
#load the training data from a pickled file using the configuration data
training_data = utils.pickle_load(config_data['data_train_path'])

# %%
#display information about the training data
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204277 entries, 15826 to 7493
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Age             204277 non-null  int64
#  1   Income          204277 non-null  int64
#  2   LoanAmount      204277 non-null  int64
#  3   MonthsEmployed  204277 non-null  int64
#  4   NumCreditLines  204277 non-null  int64
#  5   InterestRate    204277 non-null  float64
#  6   LoanTerm        204277 non-null  int64
#  7   DTIRatio        204277 non-null  float64
#  8   Education       204277 non-null  object
#  9   EmploymentType  204277 non-null  object
#  10  MaritalStatus   204277 non-null  object
#  11  HasMortgage     204277 non-null  object
#  12  HasDependents   204277 non-null  object
#  13  LoanPurpose     204277 non-null  object
#  14  HasCoSigner     204277 non-null  object
#  15  Default         204277 non-null  int64
# dtypes: float64(2), int64(7), object(7)
# memory usage: 26.5+ MB

# %% [markdown]
# Create a function for binning the numerical predictors (Age, Income, LoanAmount, MonthsEmployed, NumCreditLines, InterestRate, LoanTerm, and DTIRatio)

# %%
def create_binning(data, predictor_label, num_of_bins):
    """
    Bin a numerical predictor into the specified number of bins

    Parameters
    ----------
    data : DataFrame
        The DataFrame containing the data
    predictor_label : Str
        The label of the numerical predictor column
    num_of_bins : Int
        The number of bins to create
    
    Returns
    -------
    pd.DataFrame : The DataFrame with a bew column containing the binned predictor values
    """
    #create a new column containing the binned predictor
    data[predictor_label + "_binned"] = pd.qcut(data[predictor_label],
                                             q = num_of_bins,
                                             duplicates='drop')

    return data

# %%
def binned_data(type):
    """
    Bin the numerical column in the concatenated data
    
    Parameters
    ----------
    type : Str
        The type of data

    Returns
    -------
    pd.DataFrame : The DataFrame with binned numerical columns    
    """
    #load the concatenated data
    data = utils.pickle_load(config_data[f'data_{type}_path'])

    #bin the numerical columns
    numeric_col = config_data['numeric_col']
    num_of_bins = config_data['num_of_bins']

    for column in numeric_col:
        bin_data = create_binning(data = data,
                                         predictor_label = column,
                                         num_of_bins = num_of_bins)

    #validate
    print(f"Original data shape : ", data.shape)
    print(f"Binned data shape  : ", bin_data.shape)

    #dump binned data
    utils.pickle_dump(bin_data, config_data[f'data_{type}_binned_path'])
        
    return bin_data

# %%
#check the function
bin_training_data = binned_data(type='train')
bin_training_data.T
# Out:
# Original data shape :  (204277, 24)
# Binned data shape  :  (204277, 24)
#                                      15826                 147371  \
# Age                                      45                    48
# Income                                37039                133963
# LoanAmount                           247916                 66275
# MonthsEmployed                           19                   119
# NumCreditLines                            2                     3
# InterestRate                           4.62                 14.72
# LoanTerm                                 60                    48
# DTIRatio                               0.85                  0.49
# Education                       High School                   PhD
# EmploymentType                   Unemployed         Self-employed
# MaritalStatus                       Married               Married
# HasMortgage                              No                   Yes
# HasDependents                           Yes                   Yes
# LoanPurpose                            Auto                 Other
# HasCoSigner                              No                   Yes
# Default                                   0                     0
# Age_binned                     (38.0, 49.0]          (38.0, 49.0]
# Income_binned          (14999.999, 42062.0]  (123007.0, 149999.0]
# LoanAmount_binned      (201339.8, 249999.0]   (53711.4, 103028.0]
# MonthsEmployed_binned        (-0.001, 24.0]         (96.0, 119.0]
# NumCreditLines_binned          (0.999, 2.0]            (2.0, 3.0]
# InterestRate_binned           (1.999, 6.62]        (11.17, 15.75]
# LoanTerm_binned                (36.0, 60.0]          (36.0, 60.0]
# DTIRatio_binned                 (0.74, 0.9]          (0.42, 0.58]
#
#                                     178180                126915  \
# Age                                     47                    42
# Income                              100204                 36078
# LoanAmount                            6967                 25966
# MonthsEmployed                         108                     2
# NumCreditLines                           3                     3
# InterestRate                          5.51                 18.29
# LoanTerm                                24                    36
# DTIRatio                              0.76                  0.76
# Education                      High School            Bachelor's
# EmploymentType               Self-employed         Self-employed
# MaritalStatus                       Single               Married
# HasMortgage                            Yes                    No
# HasDependents                          Yes                   Yes
# LoanPurpose                       Business             Education
# HasCoSigner                            Yes                    No
# Default                                  0                     0
# Age_binned                    (38.0, 49.0]          (38.0, 49.0]
# Income_binned          (96027.6, 123007.0]  (14999.999, 42062.0]
# LoanAmount_binned      (4999.999, 53711.4]   (4999.999, 53711.4]
# MonthsEmployed_binned        (96.0, 119.0]        (-0.001, 24.0]
# NumCreditLines_binned           (2.0, 3.0]            (2.0, 3.0]
# InterestRate_binned          (1.999, 6.62]         (15.75, 20.4]
# LoanTerm_binned             (11.999, 24.0]          (24.0, 36.0]
# DTIRatio_binned                (0.74, 0.9]           (0.74, 0.9]
#
#                                      163930               54422   \
# Age                                      20                   42
# Income                                99464                61602
# LoanAmount                           248557                78867
# MonthsEmployed                           74                  113
# NumCreditLines                            3                    3
# InterestRate                          19.45                22.24
# LoanTerm                                 60                   24
# DTIRatio                               0.45                 0.43
# Education                        Bachelor's          High School
# EmploymentType                    Part-time           Unemployed
# MaritalStatus                      Divorced               Single
# HasMortgage                              No                  Yes
# HasDependents                            No                   No
# LoanPurpose                            Auto                 Auto
# HasCoSigner                             Yes                  Yes
# Default                                   1                    0
# Age_binned                   (17.999, 28.0]         (38.0, 49.0]
# Income_binned           (96027.6, 123007.0]   (42062.0, 69093.0]
# LoanAmount_binned      (201339.8, 249999.0]  (53711.4, 103028.0]
# MonthsEmployed_binned          (72.0, 96.0]        (96.0, 119.0]
# NumCreditLines_binned            (2.0, 3.0]           (2.0, 3.0]
# InterestRate_binned           (15.75, 20.4]         (20.4, 25.0]
# LoanTerm_binned                (36.0, 60.0]       (11.999, 24.0]
# DTIRatio_binned                (0.42, 0.58]         (0.42, 0.58]
#
#                                      180728                198671  \
# Age                                      37                    54
# Income                               106031                148090
# LoanAmount                           219866                102452
# MonthsEmployed                           51                    26
# NumCreditLines                            2                     4
# InterestRate                            3.8                 16.13
# LoanTerm                                 24                    60
# DTIRatio                               0.28                  0.53
# Education                               PhD              Master's
# EmploymentType                   Unemployed         Self-employed
# MaritalStatus                      Divorced               Married
# HasMortgage                             Yes                    No
# HasDependents                            No                   Yes
# LoanPurpose                           Other             Education
# HasCoSigner                             Yes                   Yes
# Default                                   0                     0
# Age_binned                     (28.0, 38.0]          (49.0, 59.0]
# Income_binned           (96027.6, 123007.0]  (123007.0, 149999.0]
# LoanAmount_binned      (201339.8, 249999.0]   (53711.4, 103028.0]
# MonthsEmployed_binned          (48.0, 72.0]          (24.0, 48.0]
# NumCreditLines_binned          (0.999, 2.0]            (3.0, 4.0]
# InterestRate_binned           (1.999, 6.62]         (15.75, 20.4]
# LoanTerm_binned              (11.999, 24.0]          (36.0, 60.0]
# DTIRatio_binned                (0.26, 0.42]          (0.42, 0.58]
#
#                                      50465                 68947   ...  \
# Age                                      26                    43  ...
# Income                                23724                143641  ...
# LoanAmount                            74526                 64944  ...
# MonthsEmployed                           42                    39  ...
# NumCreditLines                            4                     4  ...
# InterestRate                          20.31                 22.38  ...
# LoanTerm                                 12                    24  ...
# DTIRatio                               0.55                  0.67  ...
# Education                        Bachelor's           High School  ...
# EmploymentType                    Part-time            Unemployed  ...
# MaritalStatus                       Married                Single  ...
# HasMortgage                              No                   Yes  ...
# HasDependents                            No                   Yes  ...
# LoanPurpose                            Home              Business  ...
# HasCoSigner                             Yes                   Yes  ...
# Default                                   0                     0  ...
# Age_binned                   (17.999, 28.0]          (38.0, 49.0]  ...
# Income_binned          (14999.999, 42062.0]  (123007.0, 149999.0]  ...
# LoanAmount_binned       (53711.4, 103028.0]   (53711.4, 103028.0]  ...
# MonthsEmployed_binned          (24.0, 48.0]          (24.0, 48.0]  ...
# NumCreditLines_binned            (3.0, 4.0]            (3.0, 4.0]  ...
# InterestRate_binned           (15.75, 20.4]          (20.4, 25.0]  ...
# LoanTerm_binned              (11.999, 24.0]        (11.999, 24.0]  ...
# DTIRatio_binned                (0.42, 0.58]          (0.58, 0.74]  ...
#
#                                      132667                73318   \
# Age                                      52                    36
# Income                               108360                 22468
# LoanAmount                           133462                 58993
# MonthsEmployed                          107                    48
# NumCreditLines                            3                     2
# InterestRate                           3.38                 16.44
# LoanTerm                                 48                    24
# DTIRatio                               0.85                  0.51
# Education                          Master's           High School
# EmploymentType                    Part-time             Part-time
# MaritalStatus                        Single                Single
# HasMortgage                              No                    No
# HasDependents                           Yes                   Yes
# LoanPurpose                        Business             Education
# HasCoSigner                              No                    No
# Default                                   0                     0
# Age_binned                     (49.0, 59.0]          (28.0, 38.0]
# Income_binned           (96027.6, 123007.0]  (14999.999, 42062.0]
# LoanAmount_binned      (103028.0, 151975.2]   (53711.4, 103028.0]
# MonthsEmployed_binned         (96.0, 119.0]          (24.0, 48.0]
# NumCreditLines_binned            (2.0, 3.0]          (0.999, 2.0]
# InterestRate_binned           (1.999, 6.62]         (15.75, 20.4]
# LoanTerm_binned                (36.0, 60.0]        (11.999, 24.0]
# DTIRatio_binned                 (0.74, 0.9]          (0.42, 0.58]
#
#                                      182558                121355  \
# Age                                      68                    36
# Income                                73103                 32799
# LoanAmount                           108073                226588
# MonthsEmployed                           43                    82
# NumCreditLines                            4                     3
# InterestRate                           6.58                  23.6
# LoanTerm                                 60                    24
# DTIRatio                                0.1                  0.74
# Education                        Bachelor's            Bachelor's
# EmploymentType                   Unemployed             Part-time
# MaritalStatus                      Divorced              Divorced
# HasMortgage                              No                    No
# HasDependents                           Yes                    No
# LoanPurpose                           Other                  Auto
# HasCoSigner                             Yes                   Yes
# Default                                   0                     0
# Age_binned                     (59.0, 69.0]          (28.0, 38.0]
# Income_binned            (69093.0, 96027.6]  (14999.999, 42062.0]
# LoanAmount_binned      (103028.0, 151975.2]  (201339.8, 249999.0]
# MonthsEmployed_binned          (24.0, 48.0]          (72.0, 96.0]
# NumCreditLines_binned            (3.0, 4.0]            (2.0, 3.0]
# InterestRate_binned           (1.999, 6.62]          (20.4, 25.0]
# LoanTerm_binned                (36.0, 60.0]        (11.999, 24.0]
# DTIRatio_binned               (0.099, 0.26]          (0.58, 0.74]
#
#                                      34697                 59108   \
# Age                                      40                    18
# Income                                46265                115282
# LoanAmount                           148883                142016
# MonthsEmployed                          115                    50
# NumCreditLines                            3                     3
# InterestRate                            8.7                  3.43
# LoanTerm                                 48                    36
# DTIRatio                               0.58                  0.36
# Education                       High School              Master's
# EmploymentType                   Unemployed            Unemployed
# MaritalStatus                       Married              Divorced
# HasMortgage                             Yes                    No
# HasDependents                           Yes                    No
# LoanPurpose                       Education              Business
# HasCoSigner                             Yes                   Yes
# Default                                   0                     0
# Age_binned                     (38.0, 49.0]        (17.999, 28.0]
# Income_binned            (42062.0, 69093.0]   (96027.6, 123007.0]
# LoanAmount_binned      (103028.0, 151975.2]  (103028.0, 151975.2]
# MonthsEmployed_binned         (96.0, 119.0]          (48.0, 72.0]
# NumCreditLines_binned            (2.0, 3.0]            (2.0, 3.0]
# InterestRate_binned           (6.62, 11.17]         (1.999, 6.62]
# LoanTerm_binned                (36.0, 60.0]          (24.0, 36.0]
# DTIRatio_binned                (0.42, 0.58]          (0.26, 0.42]
#
#                                      71610                85645   \
# Age                                      67                   60
# Income                                39547                48470
# LoanAmount                            94145                29331
# MonthsEmployed                           82                   42
# NumCreditLines                            4                    1
# InterestRate                           3.32                12.67
# LoanTerm                                 48                   12
# DTIRatio                                0.8                 0.83
# Education                               PhD          High School
# EmploymentType                   Unemployed        Self-employed
# MaritalStatus                       Married               Single
# HasMortgage                              No                   No
# HasDependents                            No                   No
# LoanPurpose                            Auto                 Auto
# HasCoSigner                             Yes                   No
# Default                                   0                    0
# Age_binned                     (59.0, 69.0]         (59.0, 69.0]
# Income_binned          (14999.999, 42062.0]   (42062.0, 69093.0]
# LoanAmount_binned       (53711.4, 103028.0]  (4999.999, 53711.4]
# MonthsEmployed_binned          (72.0, 96.0]         (24.0, 48.0]
# NumCreditLines_binned            (3.0, 4.0]         (0.999, 2.0]
# InterestRate_binned           (1.999, 6.62]       (11.17, 15.75]
# LoanTerm_binned                (36.0, 60.0]       (11.999, 24.0]
# DTIRatio_binned                 (0.74, 0.9]          (0.74, 0.9]
#
#                                     21010                 7493
# Age                                     37                    44
# Income                               56697                115809
# LoanAmount                           76419                114482
# MonthsEmployed                          15                    22
# NumCreditLines                           2                     4
# InterestRate                         19.61                  5.23
# LoanTerm                                60                    36
# DTIRatio                              0.24                  0.16
# Education                      High School              Master's
# EmploymentType                   Part-time         Self-employed
# MaritalStatus                     Divorced                Single
# HasMortgage                            Yes                   Yes
# HasDependents                          Yes                   Yes
# LoanPurpose                          Other             Education
# HasCoSigner                             No                    No
# Default                                  0                     0
# Age_binned                    (28.0, 38.0]          (38.0, 49.0]
# Income_binned           (42062.0, 69093.0]   (96027.6, 123007.0]
# LoanAmount_binned      (53711.4, 103028.0]  (103028.0, 151975.2]
# MonthsEmployed_binned       (-0.001, 24.0]        (-0.001, 24.0]
# NumCreditLines_binned         (0.999, 2.0]            (3.0, 4.0]
# InterestRate_binned          (15.75, 20.4]         (1.999, 6.62]
# LoanTerm_binned               (36.0, 60.0]          (24.0, 36.0]
# DTIRatio_binned              (0.099, 0.26]         (0.099, 0.26]
#
# [24 rows x 204277 columns]

# %% [markdown]
# #### **3.2 WoE and IV**

# %% [markdown]
# To assess the strength of each characteristic individually as a predictor of the credit performance. Create a contingency table/crosstab for all predictors: numerical and categorical predictors.

# %%
def create_list_crosstab():
    """
    Generate the crosstab list (contingency table) for WOE and IV calculation. Only in training data
    
    Returns
    -------
    list : A list of contingency tables for each numerical and categorical predictor
    """
    #load the binned train data
    bin_training_data = utils.pickle_load(config_data['data_train_binned_path'])

    #load the response variable (we will summarize based on the response variable)
    response_variable = config_data['response_variable']

    #iterate over numercial columns
    numeric_crosstab = []
    numeric_col = config_data['numeric_col']
    for column in numeric_col:
        #create a contingency table
        crosstab = pd.crosstab(bin_training_data[column + "_binned"],
                               bin_training_data[response_variable],
                               margins = True)

        #append to the list
        numeric_crosstab.append(crosstab)

    #iterate over categorical columns
    categoric_crosstab = []
    categoric_col = config_data['categoric_col']
    for column in categoric_col:
        #create a contingency table
        crosstab = pd.crosstab(bin_training_data[column],
                               bin_training_data[response_variable],
                               margins = True)

        #append to the list
        categoric_crosstab.append(crosstab)

    #put all two in a crosstab_list
    list_crosstab = numeric_crosstab + categoric_crosstab

    #validate the crosstab_list
    print('number of num bin : ', [bin.shape for bin in numeric_crosstab])
    print('number of cat bin : ', [bin.shape for bin in categoric_crosstab])

    #dump the result
    utils.pickle_dump(list_crosstab, config_data['crosstab_list_path'])

    return list_crosstab

# %%
#check the function
list_crosstab = create_list_crosstab()
list_crosstab[0]
# Out:
# number of num bin :  [(6, 3), (6, 3), (6, 3), (6, 3), (4, 3), (6, 3), (4, 3), (6, 3)]
# number of cat bin :  [(5, 3), (5, 3), (4, 3), (3, 3), (3, 3), (6, 3), (3, 3)]
# Default              0      1     All
# Age_binned
# (17.999, 28.0]   34379   8577   42956
# (28.0, 38.0]     33751   5775   39526
# (38.0, 49.0]     38708   4433   43141
# (49.0, 59.0]     36590   2918   39508
# (59.0, 69.0]     37127   2019   39146
# All             180555  23722  204277

# %%
list_crosstab[14]
# Out:
# Default           0      1     All
# HasCoSigner
# No            89030  13084  102114
# Yes           91525  10638  102163
# All          180555  23722  204277

# %% [markdown]
# Calculate the WOE and IV for each crosstab.
#
# - Weight of Evidence (WoE) — measures the strength of each attribute.
#
# $$
# \begin{align*}
# W_i &= \ln ( \% \text{Good} / \% \text{Bad} ) \\
# W_i &= \ln \left ( \left ( \frac{N_i}{\sum N} \right ) / \left ( \frac{P_i}{\sum P} \right )\right ) \\
# \end{align*}
# $$
#
# - Information Value (IV) — measures the total strength of the characteristic.
#
# $$
# \begin{align*}
# IV &= \sum_{i=1}^{n} ( \% \text{Good} - \% \text{Bad} ) \times W_i \\
# IV &= \sum_{i=1}^{n}\left [ \left ( \frac{N_i}{\sum N} - \frac{P_i}{\sum P} \right ) \times W_i \right ] \\
# \end{align*}
# $$

# %%
def WOE_and_IV():
    """
    Get the WoE and IV for each characteristic
    Calculates WOE and IV for each characteristic based on the provided contingency tables

    Returns
    -------
    tuple : two DataFrames, the first containing WOE values, and the second containing IV values
    """
    #load the crosstab list
    list_crosstab = utils.pickle_load(config_data['crosstab_list_path'])

    #create initial storage for WoE and IV
    WOE_list, IV_list = [], []
    
    #perform the calculation for all crosstab list
    for crosstab in list_crosstab:
        #calculate the WoE and IV
        #------------------------
        #calculate % Good
        crosstab['p_good'] = crosstab[0]/crosstab[0]['All']    
        #calculate % Bad                             
        crosstab['p_bad'] = crosstab[1]/crosstab[1]['All']      
        #calculate the WOE                            
        crosstab['WOE'] = np.log(crosstab['p_good']/crosstab['p_bad'])       
        #calculate the contribution value for IV               
        crosstab['contribution'] = (crosstab['p_good']-crosstab['p_bad'])*crosstab['WOE']   
                
        #append to list
        IV = crosstab['contribution'][:-1].sum()
        add_IV = {'Characteristic': crosstab.index.name, 
                  'Information Value': IV}

        WOE_list.append(crosstab)
        IV_list.append(add_IV)


    #create WOE tabke
    #create initial table to summarize the WOE values
    WOE_table = pd.DataFrame({'Characteristic': [],
                              'Attribute': [],
                              'WOE': []})
    for i in range(len(list_crosstab)):
        #define crosstab and reset index
        crosstab = list_crosstab[i].reset_index()

        #save the characteristic name
        char_name = crosstab.columns[0]

        #only use two columns (Attribute name and its WOE value)
        #drop the last row (average/total WOE)
        crosstab = crosstab.iloc[:-1, [0,-2]]
        crosstab.columns = ['Attribute', 'WOE']

        #add the characteristic name in a column
        crosstab['Characteristic'] = char_name

        WOE_table = pd.concat((WOE_table, crosstab), 
                                axis = 0)

        #reorder the column
        WOE_table.columns = ['Characteristic',
                            'Attribute',
                            'WOE']
    

    #crate IV table
    #create the initial table for IV
    IV_table = pd.DataFrame({'Characteristic': [],
                             'Information Value' : []})
    IV_table = pd.DataFrame(IV_list)

    #define the predictive power of each characteristic
    strength = []

    #assign the rule of thumb regarding IV
    for iv in IV_table['Information Value']:
        if iv < 0.02:
            strength.append('Unpredictive')
        elif iv >= 0.02 and iv < 0.1:
            strength.append('Weak')
        elif iv >= 0.1 and iv < 0.3:
            strength.append('Medium')
        else:
            strength.append('Strong')

    #assign the strength to each characteristic
    IV_table = IV_table.assign(Strength = strength)

    #sort the table by the IV values
    IV_table = IV_table.sort_values(by='Information Value')
    
    #validate
    print('WOE table shape : ', WOE_table.shape)
    print('IV table shape  : ', IV_table.shape)

    #dump data
    utils.pickle_dump(WOE_table, config_data['WOE_table_path'])
    utils.pickle_dump(IV_table, config_data['IV_table_path']) 

    return WOE_table, IV_table

# %%
#check the function
WOE_table, IV_table = WOE_and_IV()
# Out:
# WOE table shape :  (58, 3)
# IV table shape  :  (15, 3)

# %%
#display WOE table
WOE_table
# Out:
#           Characteristic             Attribute       WOE
# 0             Age_binned        (17.999, 28.0] -0.641271
# 1             Age_binned          (28.0, 38.0] -0.264161
# 2             Age_binned          (38.0, 49.0]  0.137337
# 3             Age_binned          (49.0, 59.0]  0.499244
# 4             Age_binned          (59.0, 69.0]  0.882110
# 0          Income_binned  (14999.999, 42062.0] -0.553031
# 1          Income_binned    (42062.0, 69093.0]  0.031519
# 2          Income_binned    (69093.0, 96027.6]  0.182972
# 3          Income_binned   (96027.6, 123007.0]  0.245767
# 4          Income_binned  (123007.0, 149999.0]  0.284585
# 0      LoanAmount_binned   (4999.999, 53711.4]  0.398000
# 1      LoanAmount_binned   (53711.4, 103028.0]  0.208702
# 2      LoanAmount_binned  (103028.0, 151975.2]  0.043436
# 3      LoanAmount_binned  (151975.2, 201339.8] -0.156488
# 4      LoanAmount_binned  (201339.8, 249999.0] -0.358424
# 0  MonthsEmployed_binned        (-0.001, 24.0] -0.382546
# 1  MonthsEmployed_binned          (24.0, 48.0] -0.173849
# 2  MonthsEmployed_binned          (48.0, 72.0]  0.047652
# 3  MonthsEmployed_binned          (72.0, 96.0]  0.244616
# 4  MonthsEmployed_binned         (96.0, 119.0]  0.466979
# 0  NumCreditLines_binned          (0.999, 2.0]  0.085275
# 1  NumCreditLines_binned            (2.0, 3.0] -0.042710
# 2  NumCreditLines_binned            (3.0, 4.0] -0.116096
# 0    InterestRate_binned         (1.999, 6.62]  0.678131
# 1    InterestRate_binned         (6.62, 11.17]  0.349219
# 2    InterestRate_binned        (11.17, 15.75]  0.053646
# 3    InterestRate_binned         (15.75, 20.4] -0.229457
# 4    InterestRate_binned          (20.4, 25.0] -0.519417
# 0        LoanTerm_binned        (11.999, 24.0]  0.006070
# 1        LoanTerm_binned          (24.0, 36.0] -0.000626
# 2        LoanTerm_binned          (36.0, 60.0] -0.005742
# 0        DTIRatio_binned         (0.099, 0.26]  0.109887
# 1        DTIRatio_binned          (0.26, 0.42]  0.040058
# 2        DTIRatio_binned          (0.42, 0.58] -0.016666
# 3        DTIRatio_binned          (0.58, 0.74] -0.051781
# 4        DTIRatio_binned           (0.74, 0.9] -0.077760
# 0              Education            Bachelor's -0.043172
# 1              Education           High School -0.115489
# 2              Education              Master's  0.072330
# 3              Education                   PhD  0.099289
# 0         EmploymentType             Full-time  0.229125
# 1         EmploymentType             Part-time -0.028895
# 2         EmploymentType         Self-employed  0.008476
# 3         EmploymentType            Unemployed -0.176270
# 0          MaritalStatus              Divorced -0.082647
# 1          MaritalStatus               Married  0.113294
# 2          MaritalStatus                Single -0.023328
# 0            HasMortgage                    No -0.067980
# 1            HasMortgage                   Yes  0.071661
# 0          HasDependents                    No -0.107344
# 1          HasDependents                   Yes  0.116667
# 0            LoanPurpose                  Auto -0.021700
# 1            LoanPurpose              Business -0.075896
# 2            LoanPurpose             Education -0.021859
# 3            LoanPurpose                  Home  0.139877
# 4            LoanPurpose                 Other -0.010732
# 0            HasCoSigner                    No -0.112049
# 1            HasCoSigner                   Yes  0.122547

# %%
#display IV table
IV_table
# Out:
#            Characteristic  Information Value      Strength
# 6         LoanTerm_binned           0.000028  Unpredictive
# 7         DTIRatio_binned           0.004507  Unpredictive
# 11            HasMortgage           0.004870  Unpredictive
# 13            LoanPurpose           0.005125  Unpredictive
# 10          MaritalStatus           0.006637  Unpredictive
# 4   NumCreditLines_binned           0.007504  Unpredictive
# 8               Education           0.007595  Unpredictive
# 12          HasDependents           0.012510  Unpredictive
# 14            HasCoSigner           0.013716  Unpredictive
# 9          EmploymentType           0.020510          Weak
# 2       LoanAmount_binned           0.070210          Weak
# 3   MonthsEmployed_binned           0.088040          Weak
# 1           Income_binned           0.107174        Medium
# 5     InterestRate_binned           0.169802        Medium
# 0              Age_binned           0.274535        Medium
